# %%
import numpy as np
arr= np.random.rand(10,1)
x=np.mean(arr)
print(x)
# Out:
# 0.6167456691539888

# %%
import numpy as np
arr= np.random.rand(20,1)
x=np.var(arr)
y=np.std(arr)
print(x)
print(y)
# Out:
# 0.10225112674096393
# 0.31976730092516326

# %%
import numpy as np
arr1= np.random.rand(10,20)
arr2= np.random.rand(20,25)
print(np.dot(arr1,arr2))
x=np.dot(arr1,arr2)
y=np.add(x)
print(y)
# Out:
# [[6.11962488 5.97594751 5.07310609 4.2435621  4.70422534 4.74990145
#   4.78331844 4.27523241 4.52778145 5.48074431 5.24849714 4.95601117
#   4.79505588 4.96982618 4.40371031 4.46452523 3.60235163 3.99818908
#   4.67391551 3.98238168 5.3504028  4.4717384  4.48389015 3.97718979
#   4.860682  ]
#  [6.43002136 6.70426156 5.13021905 4.85096258 5.31818961 5.51226794
#   6.02233202 5.14400608 4.32997038 6.38927157 6.08439972 6.08302571
#   5.20664739 4.676163   4.80592977 5.28383248 5.29778204 4.86570375
#   5.26708961 3.90633477 6.3237732  4.87692001 5.14367325 4.81485293
#   6.11451716]
#  [6.25591209 7.03191425 5.22438217 5.19727764 4.53617642 5.43508673
#   5.00625342 4.19884237 5.36692742 6.42479705 5.36176062 5.9000003
#   5.31635091 4.44600427 4.33890622 5.25319764 4.38494398 4.9416542
#   4.97417175 4.36125739 5.8550013  3.93193309 4.5194312  5.02643001
#   5.43577541]
#  [6.84800363 7.50044303 5.62676494 5.53486102 6.23320303 6.65123671
#   6.47321776 4.93585075 5.35381132 7.08870122 6.55169932 6.60215089
#   6.2476255  4.61831713 5.7343337  5.73682133 6.9367104  5.64476899
#   5.38069534 4.4533813  6.5366159  5.29533009 5.82769946 5.71010669
#   6.94867959]
#  [6.60610687 6.174565   4.290321   4.22692413 5.49156084 5.44957686
#   5.75105542 4.44140005 4.93342001 5.96269141 6.3602045  5.73371032
#   5.21070935 4.04822464 4.62487427 4.47776052 5.06797776 5.91066496
#   5.16979866 2.99865046 5.85241019 3.91467823 5.49976486 4.55669811
#   6.08136612]
#  [3.9292939  4.32578201 3.30742247 3.01905998 3.39563838 3.5357795
#   3.58454866 2.79657858 3.85997632 4.03405488 4.33019504 3.65910148
#   3.71790381 3.5092496  3.73939009 3.82366088 2.48601285 3.51801597
#   4.16549815 1.99230139 3.91603251 2.5620225  3.96917668 2.99706317
#   4.19956417]
#  [5.23424789 6.29391072 4.70928233 4.88779816 5.0945056  5.24735086
#   4.58639471 3.8633578  4.13198041 5.3075877  5.26605243 5.54245434
#   4.87597766 3.95623713 5.11566055 5.31715795 4.28079888 4.56924825
#   5.09627881 3.71374462 5.91138493 4.16978931 5.15219685 4.46045002
#   4.5385167 ]
#  [5.94707935 5.99138836 5.31453966 4.8032186  4.69074377 5.52636784
#   5.51595077 4.67333755 4.4844642  5.93244281 5.53109527 5.43893861
#   5.06467888 4.60267157 4.18845256 4.39091699 4.6448693  4.42179163
#   5.25902659 4.37582084 5.50602116 5.08499126 4.14219883 4.21256224
#   6.02087108]
#  [6.62367585 7.38517784 4.91100047 5.46252099 5.74866093 5.17799168
#   6.38682505 5.0970818  5.12619833 6.45975822 6.49478494 6.88699108
#   5.26510513 4.42249663 5.37421397 5.90367641 5.24752333 5.51792473
#   5.48641051 4.47174998 6.33648485 5.20098204 5.49620886 5.28607629
#   6.45117877]
#  [5.86190888 5.83105837 4.29470252 4.15164245 4.58671183 4.88678403
#   5.32299674 4.36695559 4.43618675 4.99738509 5.27048918 5.35616291
#   4.53625378 4.24206508 3.70073672 3.79405897 4.49843121 4.25025903
#   3.91231886 3.62467327 5.14113833 4.06707807 4.10155756 4.06104667
#   5.25253374]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-e63063d821a7> in <module>()
#       4 print(np.dot(arr1,arr2))
#       5 x=np.dot(arr1,arr2)
# ----> 6 y=np.add(x)
#       7 print(y)
#
# ValueError: invalid number of arguments

# %%
import numpy as np
A = np.random.rand(10,1)

print(A)

def func(x):
    return (1 / (1 + np.exp(-x)))
result = np.apply_along_axis(func, 0, A)
print(result)
# Out:
# [[0.38426393]
#  [0.90372578]
#  [0.16063302]
#  [0.48967753]
#  [0.79143447]
#  [0.37199619]
#  [0.06711727]
#  [0.78658355]
#  [0.28320557]
#  [0.84622212]]
# [[0.5949011 ]
#  [0.71171455]
#  [0.54007213]
#  [0.62003046]
#  [0.68813926]
#  [0.59194124]
#  [0.51677302]
#  [0.68709728]
#  [0.57033194]
#  [0.69977405]]
